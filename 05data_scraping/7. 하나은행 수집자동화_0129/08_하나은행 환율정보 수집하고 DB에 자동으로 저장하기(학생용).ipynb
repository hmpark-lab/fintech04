# %% [markdown]
# # 08_하나은행 환율정보 수집하고 DB에 자동으로 저장하기_수집자동화

# %%
import os
import requests
import pandas as pd
import time
from datetime import datetime

# %%
def exrate_get(tmd_dash, ymd):
url = 'https://www.kebhana.com/cms/rate/wpfxd651_01i_01.do'
payload = dict(ajax="true", tmpInqStrDt= ymd_dash, pbldDvCd="3",inqStrDt=ymd, inqKindCd="1", requestTarget="searchContentDiv")
r = requests.get(url, params=payload)
df = pd.read_html(r.text)[0]
df.insert(0,'날짜',ymd_dash)
return df
# Out:
#   Cell In[17], line 2
#     url = 'https://www.kebhana.com/cms/rate/wpfxd651_01i_01.do'
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %% [markdown]
# # 날짜 생성하기

# %%
result = []
for date in list(pd.date_range('2025-01-28', '2026-01-28', freq='-1B')):
    ymd_dash, ymd=date.strftime("%Y-%m-%d"), date.strftime("%Y%m%d")
    print(ymd_dash, ymd)
    data = exrate_get(ymd_dash, ymd)
    result.append(data)
final_result = pd.concat(result)
final_result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 7
#       5     data = exrate_get(ymd_dash, ymd)
#       6     result.append(data)
# ----> 7 final_result = pd.concat(result)
#       8 final_result
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# ...

# %%
for col in final_result.columns:
    print(col)
    if col[0] !=col[1]==col[2]:
        if col[1] == "":
            print(col)
            print(col[0])
        else:
        print(col[0].strip().replace" ", "_")
    elif col[0] != col[1] != col[2]:
        print(col)
# Out:
#   Cell In[24], line 8
#     print(col[0].strip().replace" ", "_")
#     ^
# IndentationError: expected an indented block after 'else' statement on line 7

# %% [markdown]
# # 오늘 날짜 환율 정보 수집하고 DB 저장하기

# %%
today = datetime.today()
date = today.date()
ymd_dash, ymd=date.strftime("%Y-%m-%d"), date.strftime("%Y%m%d")
print(ymd_dash, ymd)
# Out:
# 2026-01-29 20260129

# %%
for date in list(pd.date_range('2025-01-28', '2026-01-28', freq='-1B')):
    ymd_dash, ymd=date.strftime("%Y-%m-%d"), date.strftime("%Y%m%d")
    print(ymd_dash, ymd)
    new_cols_dict = flatten_cools(date)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 a, b = t_day()
#
# NameError: name 't_day' is not defined
