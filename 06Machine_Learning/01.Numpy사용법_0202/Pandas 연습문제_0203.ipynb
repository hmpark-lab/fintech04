# %%
import pandas as pd

# %%
data = [10, 20, 30, 40, 50]
s = pd.Series(data)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
r = s.tolist()
r
# Out:
# [10, 20, 30, 40, 50]

# %%
a = pd.Series([1, 2, 3, 4])
b = pd.Series([5, 6, 7, 8])
print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 0     6
# 1     8
# 2    10
# 3    12
# dtype: int64
# 0   -4
# 1   -4
# 2   -4
# 3   -4
# dtype: int64
# 0     5
# 1    12
# 2    21
# 3    32
# dtype: int64
# 0    0.200000
# 1    0.333333
# 2    0.428571
# 3    0.500000
# dtype: float64

# %%
d = {'a': 100, 'b': 200, 'c': 300, 'd': 400}
s2 = pd.Series(d)
s2
# Out:
# a    100
# b    200
# c    300
# d    400
# dtype: int64

# %%
import numpy as np
arr = np.array([10,20,30])
s3 = pd.Series(arr)
s3
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
